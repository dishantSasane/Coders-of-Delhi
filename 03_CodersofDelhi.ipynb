# %%
import json

# %%
with open ("data2.json", "r") as f:
    data = json.load(f)

# %%
data
# Out:
# {'users': [{'id': 1,
#    'name': 'Amit',
#    'friends': [2, 3, 4, 5, 6],
#    'liked_pages': [101, 102]},
#   {'id': 2,
#    'name': 'Priya',
#    'friends': [1, 3, 5, 6, 7],
#    'liked_pages': [102, 103]},
#   {'id': 3,
#    'name': 'Rahul',
#    'friends': [1, 2, 4, 7, 8],
#    'liked_pages': [101, 103]},
#   {'id': 4, 'name': 'Sara', 'friends': [1, 3, 6, 8, 9], 'liked_pages': [104]},
#   {'id': 5,
#    'name': 'Neha',
#    'friends': [1, 2, 6, 10, 11],
#    'liked_pages': [102, 105]},
#   {'id': 6,
#    'name': 'Vikram',
#    'friends': [1, 2, 4, 5, 12],
#    'liked_pages': [106]},
#   {'id': 7,
#    'name': 'Kunal',
#    'friends': [2, 3, 8, 9, 13],
#    'liked_pages': [101, 107]},
#   {'id': 8,
#    'name': 'Anjali',
#    'friends': [3, 4, 7, 10, 14],
#    'liked_pages': [103, 108]},
#   {'id': 9,
#    'name': 'Ravi',
#    'friends': [4, 7, 10, 11, 15],
#    'liked_pages': [104, 109]},
#   {'id': 10,
#    'name': 'Sneha',
#    'friends': [5, 8, 9, 12, 16],
# ...

# %%
def people_you_may_know(data, user_id):
    suggestion = []
    direct_friends = {}

    for users in data['users']:
        if users['id'] == user_id:
            direct_friends = set(users['friends'])
        else:
            break

    for friend_id in direct_friends:
        for users in data['users']:
            if friend_id == users['id']:
                for person in users['friends']:
                    if person != user_id and person not in direct_friends:
                        suggestion.append(person)
    return suggestion




user_id = int(input("Enter a User Id: "))
recommendations = set(people_you_may_know(data, user_id))
print(f"The recommendation for {user_id} is {recommendations}")
# Out:
# The recommendation for 1 is {7, 8, 9, 10, 11, 12}

# %%
recommendations
# Out:
# [4]
